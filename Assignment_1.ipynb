# %% [markdown]
# Question :

# %% [markdown]
# Load a dataset (e.g., Iris, Titanic) and perform basic data exploration (summary statistics, missing value handling, and data visualization and explain each of them).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\OneDrive\Desktop\ML_PRAC\ML_PRAC\tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.shape
# Out:
# (418, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105'], dtype=object)

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B57 B59 B63 B66    3
# B45                2
# C89                2
# C55 C57            2
# A34                2
#                   ..
# E52                1
# D30                1
# E31                1
# C62 C64            1
# C105               1
# Name: count, Length: 76, dtype: int64

# %%
df1=df.drop(['Cabin','PassengerId','Name'],axis=1)

# %%
df1.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Embarked
# 0         0       3    male  34.5      0      0   330911   7.8292        Q
# 1         1       3  female  47.0      1      0   363272   7.0000        S
# 2         0       2    male  62.0      0      0   240276   9.6875        Q
# 3         0       3    male  27.0      0      0   315154   8.6625        S
# 4         1       3  female  22.0      1      1  3101298  12.2875        S

# %%
df['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df1['Age'].fillna(df['Age'].median())
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413    27.0
# 414    39.0
# 415    38.5
# 416    27.0
# 417    27.0
# Name: Age, Length: 418, dtype: float64

# %%
df1['Age']=df1['Age'].fillna(df['Age'].median())

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Sex       418 non-null    object
#  3   Age       418 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Embarked  418 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 29.5+ KB

# %%
df1['Fare']=df1['Fare'].fillna(df['Fare'].mean())

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Sex       418 non-null    object
#  3   Age       418 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      418 non-null    float64
#  8   Embarked  418 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 29.5+ KB

# %%
df1.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     0.363636    2.265550   29.599282    0.447368    0.392344   35.627188
# std      0.481622    0.841838   12.703770    0.896760    0.981429   55.840500
# min      0.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   23.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.750000    1.000000    0.000000   31.500000
# max      1.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
plt.figure(figsize=(12,12))
plt.subplot(3,3,1)
sns.violinplot(df['Age'],color='Red')
plt.subplot(3,3,2)
sns.countplot(x='Survived',data=df,hue='Pclass')
plt.subplot(3,3,3)
sns.boxplot(x='Fare',data=df)
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# we can check that fare has outliers, persons from pclass have high chances of dying rather than surviving

# %%
sns.pairplot(df)

# %%
x=df['Sex'].unique()

# %%
df2=pd.concat([df['Sex'],df['Survived']],axis=1,join='inner')

# %%
df2[df2['Sex']=='male'].value_counts()
# Out:
# Sex   Survived
# male  0           266
# Name: count, dtype: int64

# %%
df2[df2['Sex']=='female'].value_counts()
# Out:
# Sex     Survived
# female  1           152
# Name: count, dtype: int64

# %%
from sklearn.datasets import load_iris

# %%
df=pd.read_csv(r"D:\OneDrive\Desktop\ML_PRAC\ML_PRAC\Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
plt.figure(figsize=(8,8))
fig, axes = plt.subplots(2,2, constrained_layout=True)
plt.subplot(2,2,1)
plt.hist(df['SepalLengthCm'])
plt.title("SepalLengthCm Distribution")
plt.xlabel("SepalLengthCm Range")
plt.ylabel("Value counts")
plt.subplot(2,2,2)
plt.hist(df['SepalWidthCm'])
plt.title("SepalWidthCm Distribution")
plt.xlabel("SepalWidthCm Range")
plt.ylabel("Value counts")
plt.subplot(2,2,3)
plt.hist(df['PetalLengthCm'])
plt.title("PetalLengthCm Distribution")
plt.xlabel("PetalLengthCm Range")
plt.ylabel("Value counts")
plt.subplot(2,2,4)
plt.hist(df['PetalWidthCm'])
plt.title("PetalWidthCm Distribution")
plt.xlabel("PetalWidthCm Range")
plt.ylabel("Value counts")
plt.tight_layout()
# Out:
# C:\Users\Saswata Maity\AppData\Local\Temp\ipykernel_1944\3564484439.py:23: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
