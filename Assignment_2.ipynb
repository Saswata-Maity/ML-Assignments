# %% [markdown]
# Question 2

# %% [markdown]
# Implement simple and multiple linear regression models using Python. Use a dataset like Boston Housing. Evaluate your model using metrics such as MSE and R-squared. Demonstrate the effect of L1 and L2 regularization on the regression coefficients and interpret your results.

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\SASWATA\OneDrive\Desktop\ML_PRAC\ML_PRAC\Housing.csv")

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.shape
# Out:
# (545, 13)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['mainroad']=le.fit_transform(df['mainroad'])

# %%
df['guestroom']=le.fit_transform(df['guestroom'])

# %%
df['basement']=le.fit_transform(df['basement'])

# %%
df['hotwaterheating']=le.fit_transform(df['hotwaterheating'])

# %%
df['airconditioning']=le.fit_transform(df['airconditioning'])

# %%
df['prefarea']=le.fit_transform(df['prefarea'])

# %%
df['furnishingstatus']=le.fit_transform(df['furnishingstatus'])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
X
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((436, 12), (109, 12), (436,), (109,))

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 2.31499930e+02,  1.14288747e+05,  1.05921160e+06,  3.66254013e+05,
#         3.47930556e+05,  3.31573686e+05,  3.01557383e+05,  8.20180693e+05,
#         8.85581541e+05,  2.80315221e+05,  6.66158973e+05, -2.14539268e+05])

# %%
lr.intercept_
# Out:
# 297852.2909201896

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import r2_score,accuracy_score,mean_squared_error

# %%
y_pred=lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.737470261176379

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 975679294687.7041

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
plr=PolynomialFeatures(4)

# %%
x_t=plr.fit_transform(X_train)
x_tst=plr.fit_transform(X_test)

# %%
lr1=LinearRegression()

# %%
lr1.fit(x_t,y_train)
# Out:
# LinearRegression()

# %%
y_pred1=lr1.predict(x_tst)

# %%
r2_score(y_test,y_pred1)
# Out:
# -25.17425399354494

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
ridge=Ridge(alpha=1.0)

# %%
# Ridge Regression (L2 regularization)
ridge = Ridge(alpha=1.5)
ridge.fit(X_train, y_train)
y_pred_ridge = ridge.predict(X_test)
print("Ridge R-squared:", r2_score(y_test, y_pred_ridge))
print("Ridge MSE:", mean_squared_error(y_test, y_pred_ridge))

# Lasso Regression (L1 regularization)
lasso = Lasso(alpha=1.0)
lasso.fit(X_train, y_train)
y_pred_lasso = lasso.predict(X_test)
print("Lasso R-squared:", r2_score(y_test, y_pred_lasso))
print("Lasso MSE:", mean_squared_error(y_test, y_pred_lasso))
# Out:
# Ridge R-squared: 0.7375662729174809
# Ridge MSE: 975322471615.9265
# Lasso R-squared: 0.7374699563550137
# Lasso MSE: 975680427541.8184
